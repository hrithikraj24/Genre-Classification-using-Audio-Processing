# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa

# %%
data = pd.read_csv('mycsv_combination1.csv')

# %%
data.head()
# Out:
#             filename  zcr_mean   zcr_std  spectral_centroid  \
# 0  blues.00000_1.wav  0.078317  0.013519        1782.622682
# 1  blues.00000_2.wav  0.079108  0.015145        1803.133844
# 2  blues.00000_3.wav  0.085122  0.017463        1767.406536
# 3  blues.00001_1.wav  0.054409  0.028735        1364.273766
# 4  blues.00001_2.wav  0.051896  0.017981        1581.277785
#
#    mean_spectral_rolloff  std_spectral_rolloff  spectral_bandwidth  \
# 0            3845.075667            912.603923         2020.556328
# 1            3903.829836           1059.169428         2043.208033
# 2            3672.610197            846.426471         1944.426261
# 3            2976.303348           1565.934901         1842.030467
# 4            3786.371459           1798.029729         2125.234003
#
#    chroma_deviation_mean       mfcc1       mfcc2  ...     mfcc12    mfcc13  \
# 0               0.342053 -125.188171  120.222138  ...   9.301556 -4.159669
# ...

# %%
data[data['genre']=='country'][0:10]
# Out:
#                 filename  zcr_mean   zcr_std  spectral_centroid  \
# 600  country.00000_1.wav  0.080519  0.017473        2819.800049
# 601  country.00000_2.wav  0.112371  0.032983        2749.132774
# 602  country.00000_3.wav  0.121288  0.014552        2820.340164
# 603  country.00001_1.wav  0.127026  0.016523        2909.443994
# 604  country.00001_2.wav  0.120898  0.015286        2917.085944
# 605  country.00001_3.wav  0.124084  0.013995        2987.075736
# 606  country.00002_1.wav  0.086243  0.028833        2508.011843
# 607  country.00002_2.wav  0.057652  0.018420        1979.110035
# 608  country.00002_3.wav  0.073599  0.019627        2434.413961
# 609  country.00003_1.wav  0.102017  0.027740        2074.056455
#
#      mean_spectral_rolloff  std_spectral_rolloff  spectral_bandwidth  \
# 600            6448.619784           1570.999600         2925.729118
# 601            5912.712816           1211.464210         2753.587325
# ...

# %%
data[data['genre']=='jazz'][0:10]
# Out:
#               filename  zcr_mean   zcr_std  spectral_centroid  \
# 1200  jazz.00000_1.wav  0.096557  0.030288        1755.634267
# 1201  jazz.00000_2.wav  0.090283  0.037471        1755.557633
# 1202  jazz.00000_3.wav  0.044366  0.013980        1001.429842
# 1203  jazz.00001_1.wav  0.065655  0.015554        1425.726549
# 1204  jazz.00001_2.wav  0.065008  0.030184        1426.865257
# 1205  jazz.00001_3.wav  0.043497  0.020705         946.179185
# 1206  jazz.00002_1.wav  0.049930  0.015882        1007.179393
# 1207  jazz.00002_2.wav  0.070953  0.040646        1231.867132
# 1208  jazz.00002_3.wav  0.048185  0.014501         955.035870
# 1209  jazz.00003_1.wav  0.047216  0.009087        1110.366664
#
#       mean_spectral_rolloff  std_spectral_rolloff  spectral_bandwidth  \
# 1200            3290.733079           1542.252244         1873.436880
# 1201            3395.826102           1782.430495         1947.944539
# 1202            1714.287778            858.929249         1441.268716
# ...

# %%
data[data['genre']=='hiphop'][0:10]
# Out:
#                filename  zcr_mean   zcr_std  spectral_centroid  \
# 900  hiphop.00000_1.wav  0.146702  0.026591        2553.739732
# 901  hiphop.00000_2.wav  0.143030  0.038902        2735.084910
# 902  hiphop.00000_3.wav  0.141994  0.021096        2715.553519
# 903  hiphop.00001_1.wav  0.094645  0.023795        2761.839277
# 904  hiphop.00001_2.wav  0.093728  0.034116        2813.177086
# 905  hiphop.00001_3.wav  0.097412  0.032680        2850.285976
# 906  hiphop.00002_1.wav  0.059712  0.017345        1482.127750
# 907  hiphop.00002_2.wav  0.052784  0.013870        1435.370187
# 908  hiphop.00002_3.wav  0.057565  0.019187        1553.416397
# 909  hiphop.00003_1.wav  0.088912  0.015191        2370.565166
#
#      mean_spectral_rolloff  std_spectral_rolloff  spectral_bandwidth  \
# 900            5031.075533            949.166579         2181.613126
# 901            5704.150504           1374.741338         2433.944722
# ...

# %%
data[data['genre']=='classical'][0:10]
# Out:
#                   filename  zcr_mean   zcr_std  spectral_centroid  \
# 300  classical.00000_1.wav  0.100195  0.014734        1526.506461
# 301  classical.00000_2.wav  0.094242  0.015100        1510.741710
# 302  classical.00000_3.wav  0.093446  0.012190        1477.635352
# 303  classical.00001_1.wav  0.068403  0.015983        1280.272463
# 304  classical.00001_2.wav  0.092410  0.009603        1328.060865
# 305  classical.00001_3.wav  0.095030  0.016603        1473.406502
# 306  classical.00002_1.wav  0.093711  0.018087        1495.266058
# 307  classical.00002_2.wav  0.080707  0.015243        1430.048883
# 308  classical.00002_3.wav  0.090151  0.009419        1544.304143
# 309  classical.00003_1.wav  0.118278  0.020924        1609.368570
#
#      mean_spectral_rolloff  std_spectral_rolloff  spectral_bandwidth  \
# 300            2694.922838            428.392082         1561.054868
# 301            2807.235229            507.824321         1575.017988
# ...

# %%
data[data['genre']=='blues'][0:10]
# Out:
#             filename  zcr_mean   zcr_std  spectral_centroid  \
# 0  blues.00000_1.wav  0.078317  0.013519        1782.622682
# 1  blues.00000_2.wav  0.079108  0.015145        1803.133844
# 2  blues.00000_3.wav  0.085122  0.017463        1767.406536
# 3  blues.00001_1.wav  0.054409  0.028735        1364.273766
# 4  blues.00001_2.wav  0.051896  0.017981        1581.277785
# 5  blues.00001_3.wav  0.058335  0.021967        1644.129011
# 6  blues.00002_1.wav  0.068659  0.016906        1521.556846
# 7  blues.00002_2.wav  0.071242  0.012101        1507.457456
# 8  blues.00002_3.wav  0.083482  0.013001        1626.752119
# 9  blues.00003_1.wav  0.029266  0.010228         947.018874
#
#    mean_spectral_rolloff  std_spectral_rolloff  spectral_bandwidth  \
# 0            3845.075667            912.603923         2020.556328
# 1            3903.829836           1059.169428         2043.208033
# 2            3672.610197            846.426471         1944.426261
# ...

# %%
dataset = data[data['genre'].isin(['country', 'classical','hiphop','blues','jazz'])].drop(['filename'],axis=1)
dataset.shape
# Out:
# (1497, 28)

# %%
#KNeighbours Classification Algorithm

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier

# %%
# If you say df.iloc[:, -1] it means the last column, but df.iloc[:, :-1] means until the last column.

# %%
Y = LabelEncoder().fit_transform((dataset.iloc[:,-1]))
print(Y)
Y.shape
# Out:
# [0 0 0 ... 4 4 4]
# (1497,)

# %%
X = StandardScaler().fit_transform(np.array(dataset.iloc[:, :-1], dtype = float))
print(X)
X.shape
# Out:
# [[-0.13251553 -0.6530739  -0.11453394 ...  0.0785806  -0.12563547
#    0.89747518]
#  [-0.11010467 -0.52101128 -0.08376836 ... -0.02468127 -0.03258611
#    0.71636755]
#  [ 0.06034908 -0.33271922 -0.13735729 ...  0.03788734 -0.24626846
#    0.60844543]
#  ...
#  [-0.78505778 -0.79541252 -0.43956275 ... -0.5750611   0.44041709
#   -0.84992208]
#  [-1.07591588 -0.84841252 -0.37335638 ...  0.55097387  1.96987773
#    0.80618627]
#  [-1.36409003 -1.09403469 -0.83802076 ... -0.69249166  0.2382555
#   -0.11562557]]
# (1497, 27)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=42)
print ('Train set:', X_train.shape,  Y_train.shape)
print ('Test set:', X_test.shape,  Y_test.shape)
# Out:
# Train set: (1197, 27) (1197,)
# Test set: (300, 27) (300,)

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
pred = knn.predict(X_test)
print(pred)
# Out:
# [2 4 4 4 2 4 2 2 1 0 2 3 0 4 0 0 4 3 1 0 1 1 0 1 1 1 4 4 4 2 0 1 0 0 3 2 1
#  1 1 0 1 2 3 4 1 1 3 1 1 0 3 3 1 1 1 2 0 2 2 4 3 3 0 0 2 1 1 4 4 4 3 3 2 1
#  3 1 1 2 2 1 3 0 0 4 0 0 3 4 2 2 2 1 3 3 3 3 1 0 1 3 0 2 2 2 1 0 0 0 0 2 1
#  4 2 1 0 1 2 1 0 3 2 1 4 2 0 3 2 2 2 0 0 0 1 3 1 0 3 4 0 0 1 0 4 3 0 1 2 4
#  2 4 3 3 4 1 2 4 1 2 0 1 3 0 1 0 0 4 4 2 1 2 3 1 3 0 2 1 3 1 2 0 3 0 0 2 2
#  3 4 1 1 0 4 4 4 0 0 4 0 0 3 2 3 1 4 3 3 0 3 1 1 0 2 3 3 2 2 1 2 1 0 0 2 3
#  3 0 4 1 4 4 4 1 1 3 1 3 2 4 4 0 2 2 2 3 0 2 2 0 4 0 3 3 2 2 3 1 0 3 3 3 3
#  3 0 4 3 4 3 1 0 1 3 4 0 1 2 3 2 3 1 3 3 2 4 2 4 0 3 0 4 0 4 2 4 4 4 4 3 1
#  0 3 4 1]

# %%
print("KNN Accuracy: %.3f" % knn.score(X_test,Y_test))
# Out:
# KNN Accuracy: 0.863

# %%
from sklearn.metrics import classification_report,confusion_matrix
# print(confusion_matrix(y_test,pred))
print(classification_report(Y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86        56
#            1       0.88      0.95      0.91        59
#            2       0.83      0.89      0.86        54
#            3       0.98      0.86      0.92        71
#            4       0.82      0.70      0.76        60
#
#     accuracy                           0.86       300
#    macro avg       0.86      0.87      0.86       300
# weighted avg       0.87      0.86      0.86       300
